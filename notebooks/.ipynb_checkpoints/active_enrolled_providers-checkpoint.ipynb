# %%
# !ls
# Out:
# active_enrolled_providers_dataset.ipynb
# dry-run-notebook-get-started-here.ipynb
# licensed_healthcare_facilities.ipynb
# licensed_mental_health_facilities_dataset.ipynb
# medicare_physicians_by_provider_dataset.ipynb
# residential_mentalhealth_programs.ipynb

# %%
# !pwd
# Out:
# /home/jovyan/diverse-healthcare/notebooks

# %%
import pandas as pd

# %%
df_active_prov = pd.read_csv("/home/jovyan/diverse-healthcare/data/may-2021-active-enrolled-providers-report.csv")
df_active_prov.head()
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0,9,10,12,14,15,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Provider Number  NPI Provider Number  Owner Number   \
# 0      1003000225         1.003000e+09            1.0
# 1      1003000563         1.003001e+09            1.0
# 2      1003000563         1.003001e+09            1.0
# 3      1003000639         1.003001e+09            1.0
# 4      1003000852         1.003001e+09            1.0
#
#    Service Location Number       Provider Legal Name  \
# 0                      1.0       MORGAN, ANNA C A MD
# 1                      1.0  CHUN, RICHARD B D MD INC
# 2                      1.0  CHUN, RICHARD B D MD INC
# 3                      1.0      BENHARASH, PEYMAN MD
# 4                      1.0       COYLE, TRIONA B PHD
#
# ...
