# %%
# !ls
# Out:
# april-2021-licensed-mhrc-phf-facilities.csv  licensed_facilities_dataset.ipynb

# %%
# !pwd
# Out:
# /home/jovyan/DS4A/cecilia/licensed_facilities

# %%
import pandas as pd

# %%
df_lic_mf_fac = pd.read_csv("home/jovyan/diverse-healthcare/data/april-2021-licensed-mhrc-phf-facilities.csv")
df_lic_mf_fac.head()
# Out:
#   County Code   Record ID                            Legal Name  \
# 0          44  02 099 021                7th AVENUE CENTER, LLC
# 1          37  02 125 008  ALPINE SPECIAL TREATMENT CENTER, LLC
# 2          19  20 006 050              BALANCE TREATMENT CENTER
# 3           4  10 016 001        BUTTE COUNTY BEHAVIORAL HEALTH
# 4          24  02 098 022    CALIFORNIA PSYCHIATRIC TRANSITIONS
#
#                                       Facility Name  \
# 0                                 7th Avenue Center
# 1                   Alpine Special Treatment Center
# 2                          Balance Treatment Center
# 3              Butte County  Mental Health Services
# 4  California Psychiatric Transitions
#
#                             Physical Address Physical Address 2  \
# 0  1171 Seventh Avenue                                      NaN
# 1                      2120 Alpine Boulevard                NaN
# 2                   26039 Mulholland Highway                NaN
# ...
